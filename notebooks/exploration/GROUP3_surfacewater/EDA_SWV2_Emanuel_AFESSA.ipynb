# %% [markdown]
# ## EDA for watersurface

# %%
# import libraries 
# data importing & processing
import os
import pandas as pd
from datetime import date

# statisctics 
from statsmodels.tsa.stattools import adfuller

# dash & ploting
import dash
from dash import dcc, html, callback, Output, Input
from dash.dependencies import Input, Output
import plotly.express as px
import plotly.graph_objs as go
# Out:
# c:\Users\emanu\anaconda3\envs\hs01\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# declare paths
path_EDA =os.path.abspath(os.path.join(os.getcwd(), os.pardir))
path_notebooks = os.path.abspath(os.path.join(path_EDA, os.pardir))
path_root = os.path.abspath(os.path.join(path_notebooks, os.pardir))
# rainfall paths 
path_data = os.path.join(path_root, 'datafiles/GLDAS-2.2', 'Algiers_Ain Taya_2010_2023.csv')

# %%
print(path_root)
df_eda_sw = pd.read_csv(path_data)
df_eda_sw.info()
# Out:
# d:\WATER_SCARCITY\omdena_water_scarcity
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4929 entries, 0 to 4928
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   date               4929 non-null   object
#  1   city               4929 non-null   object
#  2   ACond_tavg         4929 non-null   float64
#  3   AvgSurfT_tavg      4929 non-null   float64
#  4   CanopInt_tavg      4929 non-null   float64
#  5   ECanop_tavg        4929 non-null   float64
#  6   ESoil_tavg         4929 non-null   float64
#  7   EvapSnow_tavg      4929 non-null   float64
#  8   Evap_tavg          4929 non-null   float64
#  9   GWS_tavg           4929 non-null   float64
#  10  Lwnet_tavg         4929 non-null   float64
#  11  Qg_tavg            4929 non-null   float64
#  12  Qh_tavg            4929 non-null   float64
#  13  Qle_tavg           4929 non-null   float64
#  14  Qsb_tavg           4929 non-null   float64
# ...

# %%
df_eda_sw['latitude'] = 36.79276
df_eda_sw['longitude'] = 3.05136

# %%
# dataframe_wgeoloaclisatio
df_eda_sw.head(5)
df_eda_sw.columns
# Out:
# Index(['date', 'city', 'ACond_tavg', 'AvgSurfT_tavg', 'CanopInt_tavg',
#        'ECanop_tavg', 'ESoil_tavg', 'EvapSnow_tavg', 'Evap_tavg', 'GWS_tavg',
#        'Lwnet_tavg', 'Qg_tavg', 'Qh_tavg', 'Qle_tavg', 'Qsb_tavg', 'Qsm_tavg',
#        'Qs_tavg', 'SnowDepth_tavg', 'SnowT_tavg', 'SoilMoist_P_tavg',
#        'SoilMoist_RZ_tavg', 'SoilMoist_S_tavg', 'SWE_tavg', 'Swnet_tavg',
#        'TVeg_tavg', 'TWS_tavg', 'latitude', 'longitude'],
#       dtype='object')

# %%
df_eda_sw.to_csv('df_latlong_Algiers_Ain Taya_2010_2023.csv', index=False)

# %% [markdown]
# # example graph

# %%
fig = px.scatter_mapbox(df_eda_sw, lat="latitude", lon="longitude", size="TWS_tavg", color="GWS_tavg", 
                        color_discrete_sequence=px.colors.sequential.Viridis, zoom=5, height=300)
fig.update_layout(mapbox_style="open-street-map")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
